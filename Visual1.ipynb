# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
lst = np.random.randint(1,10,size = 10)
lst2 = np.random.normal(100,1.5,10)
print(lst)
print(lst2)
plt.plot(lst2,lst)
plt.show()
# Out:
# [5 8 6 3 3 5 2 9 1 1]
# [100.40358575 100.07126125 101.57662292 103.44529404  97.86383451
#  100.88135852 101.02784394 102.05503478  95.83041442  96.82767598]

# %%
data = pd.read_csv("D:/Titanix/DataSet/Iris.csv")

# %%
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
data.count()
# Out:
# Id               150
# SepalLengthCm    150
# SepalWidthCm     150
# PetalLengthCm    150
# PetalWidthCm     150
# Species          150
# dtype: int64

# %%
lst = [i for i in data['SepalLengthCm']]
lst2 = [i for i in data['PetalLengthCm']]

# %%
print(lst[0:10])
lst2[0:10]
# Out:
# [5.1, 4.9, 4.7, 4.6, 5.0, 5.4, 4.6, 5.0, 4.4, 4.9]
# [1.4, 1.4, 1.3, 1.5, 1.4, 1.7, 1.4, 1.5, 1.4, 1.5]

# %%
plt.plot(lst,lst2,c ='b',linestyle = '--',linewidth = 2.5)
plt.xlabel('Sepal')
plt.ylabel('Petal')
plt.title('Sepal VS Petal')
plt.xticks([4,6,8])
plt.yticks([1,2,3,4,5,6])
plt.show()

# %%
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
plt.hist(data['SepalLengthCm'],bins = 40,cumulative = True)
plt.show()

# %%
plt.hist(data['PetalLengthCm'],bins = 15)
plt.show()

# %%
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
data.columns = ['ID','SepalL','SepalW','PetalL','PetalW','Species']

# %%
data.tail()
# Out:
#       ID  SepalL  SepalW  PetalL  PetalW         Species
# 145  146     6.7     3.0     5.2     2.3  Iris-virginica
# 146  147     6.3     2.5     5.0     1.9  Iris-virginica
# 147  148     6.5     3.0     5.2     2.0  Iris-virginica
# 148  149     6.2     3.4     5.4     2.3  Iris-virginica
# 149  150     5.9     3.0     5.1     1.8  Iris-virginica

# %%
val1 = data.iloc[:,[1,3]].copy()
val1
# Out:
#      SepalL  PetalL
# 0       5.1     1.4
# 1       4.9     1.4
# 2       4.7     1.3
# 3       4.6     1.5
# 4       5.0     1.4
# ..      ...     ...
# 145     6.7     5.2
# 146     6.3     5.0
# 147     6.5     5.2
# 148     6.2     5.4
# 149     5.9     5.1
#
# [150 rows x 2 columns]

# %%
val1.head()
# Out:
#    SepalL  PetalL
# 0     5.1     1.4
# 1     4.9     1.4
# 2     4.7     1.3
# 3     4.6     1.5
# 4     5.0     1.4

# %%
val2 = data.loc[:,['SepalW','PetalW']].copy()
val2.head()
# Out:
#    SepalW  PetalW
# 0     3.5     0.2
# 1     3.0     0.2
# 2     3.2     0.2
# 3     3.1     0.2
# 4     3.6     0.2

# %%
plt.plot(val1,label = val1.columns)
plt.legend()
plt.show()

# %%
plt.plot(val2,label = val2.columns)
plt.legend()
plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
plt.plot(val1['SepalL'],val2['SepalW'],label = ['SepalL','SepalW'],c='b',linestyle = '--')
plt.legend()
plt.show()

# %%
plt.plot(val1,val2)

# %%
val2.head()
# Out:
#    SepalW  PetalW
# 0     3.5     0.2
# 1     3.0     0.2
# 2     3.2     0.2
# 3     3.1     0.2
# 4     3.6     0.2

# %%
val1.info() == val2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   SepalL  150 non-null    float64
#  1   PetalL  150 non-null    float64
# dtypes: float64(2)
# memory usage: 2.5 KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   SepalW  150 non-null    float64
#  1   PetalW  150 non-null    float64
# dtypes: float64(2)
# memory usage: 2.5 KB
# True

# %%
val1.head()
# Out:
#    SepalL  PetalL
# 0     5.1     1.4
# 1     4.9     1.4
# 2     4.7     1.3
# 3     4.6     1.5
# 4     5.0     1.4

# %%
plt.bar(val.index,val['SepalL'], color = 'orange')
plt.xlabel('Index')
plt.ylabel('Sepal Length')
plt.yticks([4,5,6,7,8])
plt.xticks([30,60,90,120,150])
plt.title('Sepal Length wrt Index')
plt.show()

# %%
sample = val.head(20).copy()
plt.bar(sample.index ,sample['SepalL'],color = 'red',edgecolor = 'black',alpha = 0.5,hatch= '//')
# Out:
# <BarContainer object of 20 artists>
