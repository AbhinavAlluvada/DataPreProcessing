# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random
import warnings

warnings.filterwarnings('ignore')

data = pd.read_csv("D:/Titanix/DataSet/planets_updated.csv")

# %%
data
# Out:
#     Planet                                            Color  Mass (10^24kg)  \
# 0  Mercury                                             Grey           0.330
# 1    Venus                                   Brown and Grey           4.870
# 2    Earth                      Blue, Brown Green and White           5.970
# 3     Mars                               Red, Brown and Tan           0.642
# 4  Jupiter  Brown, Orange and Tan, with White cloud stripes        1898.000
# 5   Saturn                     Golden, Brown, and Blue-Grey         568.000
# 6   Uranus                                       Blue-Green          86.800
# 7  Neptune                                             Blue         102.000
#
#    Diameter (km)  Density (kg/m^3)  Surface Gravity(m/s^2)  \
# 0           4879              5429                     3.7
# 1          12104              5243                     8.9
# 2          12756              5514                     9.8
# ...

# %%
for i in data.columns:
    print(i)
# Out:
# Planet
# Color
# Mass (10^24kg)
# Diameter (km)
# Density (kg/m^3)
# Surface Gravity(m/s^2)
# Escape Velocity (km/s)
# Rotation Period (hours)
# Length of Day (hours)
# Distance from Sun (10^6 km)
# Perihelion (10^6 km)
# Aphelion (10^6 km)
# Orbital Period (days)
# Orbital Velocity (km/s)
# Orbital Inclination (degrees)
# Orbital Eccentricity
# Obliquity to Orbit (degrees)
# Mean Temperature (C)
# Surface Pressure (bars)
# Number of Moons
# Ring System?
# Global Magnetic Field?
# Surface Temperature (C)
# Atmospheric Composition
# Atmospheric Pressure (bars)
# Surface Features
# Composition

# %%
data.isnull().sum()
# Out:
# Planet                           0
# Color                            0
# Mass (10^24kg)                   0
# Diameter (km)                    0
# Density (kg/m^3)                 0
# Surface Gravity(m/s^2)           0
# Escape Velocity (km/s)           0
# Rotation Period (hours)          0
# Length of Day (hours)            0
# Distance from Sun (10^6 km)      0
# Perihelion (10^6 km)             0
# Aphelion (10^6 km)               0
# Orbital Period (days)            0
# Orbital Velocity (km/s)          0
# Orbital Inclination (degrees)    0
# Orbital Eccentricity             0
# Obliquity to Orbit (degrees)     0
# Mean Temperature (C)             0
# Surface Pressure (bars)          0
# Number of Moons                  0
# Ring System?                     0
# Global Magnetic Field?           0
# Surface Temperature (C)          0
# Atmospheric Composition          0
# Atmospheric Pressure (bars)      0
# Surface Features                 0
# Composition                      0
# ...

# %%
data = data.iloc[:,[i for i in range(10)]].copy()

# %%
data.head()
# Out:
#     Planet                                            Color  Mass (10^24kg)  \
# 0  Mercury                                             Grey           0.330
# 1    Venus                                   Brown and Grey           4.870
# 2    Earth                      Blue, Brown Green and White           5.970
# 3     Mars                               Red, Brown and Tan           0.642
# 4  Jupiter  Brown, Orange and Tan, with White cloud stripes        1898.000
#
#    Diameter (km)  Density (kg/m^3)  Surface Gravity(m/s^2)  \
# 0           4879              5429                     3.7
# 1          12104              5243                     8.9
# 2          12756              5514                     9.8
# 3           6792              3934                     3.7
# 4         142984              1326                    23.1
#
#    Escape Velocity (km/s)  Rotation Period (hours)  Length of Day (hours)  \
# 0                     4.3                   1407.6                 4222.6
# ...

# %%
data.drop(['Color'],axis = 1,inplace = True)

# %%
data.tail()
# Out:
#     Planet  Mass (10^24kg)  Diameter (km)  Density (kg/m^3)  \
# 3     Mars           0.642           6792              3934
# 4  Jupiter        1898.000         142984              1326
# 5   Saturn         568.000         120536               687
# 6   Uranus          86.800          51118              1270
# 7  Neptune         102.000          49528              1638
#
#    Surface Gravity(m/s^2)  Escape Velocity (km/s)  Rotation Period (hours)  \
# 3                     3.7                     5.0                     24.6
# 4                    23.1                    59.5                      9.9
# 5                     9.0                    35.5                     10.7
# 6                     8.7                    21.3                    -17.2
# 7                    11.0                    23.5                     16.1
#
#    Length of Day (hours)  Distance from Sun (10^6 km)
# 3                   24.7                        228.0
# ...

# %%
data.index = [i+1 for i in range(8)]

# %%
data
# Out:
#     Planet  Mass (10^24kg)  Diameter (km)  Density (kg/m^3)  \
# 1  Mercury           0.330           4879              5429
# 2    Venus           4.870          12104              5243
# 3    Earth           5.970          12756              5514
# 4     Mars           0.642           6792              3934
# 5  Jupiter        1898.000         142984              1326
# 6   Saturn         568.000         120536               687
# 7   Uranus          86.800          51118              1270
# 8  Neptune         102.000          49528              1638
#
#    Surface Gravity(m/s^2)  Escape Velocity (km/s)  Rotation Period (hours)  \
# 1                     3.7                     4.3                   1407.6
# 2                     8.9                    10.4                  -5832.5
# 3                     9.8                    11.2                     23.9
# 4                     3.7                     5.0                     24.6
# ...

# %%
val = data[data['Mass (10^24kg)']>100].copy()

# %%
val
# Out:
#     Planet  Mass (10^24kg)  Diameter (km)  Density (kg/m^3)  \
# 5  Jupiter          1898.0         142984              1326
# 6   Saturn           568.0         120536               687
# 8  Neptune           102.0          49528              1638
#
#    Surface Gravity(m/s^2)  Escape Velocity (km/s)  Rotation Period (hours)  \
# 5                    23.1                    59.5                      9.9
# 6                     9.0                    35.5                     10.7
# 8                    11.0                    23.5                     16.1
#
#    Length of Day (hours)  Distance from Sun (10^6 km)
# 5                    9.9                        778.5
# 6                   10.7                       1432.0
# 8                   16.1                       4515.0

# %%
largest_planent = data[data['Diameter (km)'] == data['Diameter (km)'].max()]

# %%
largest_planent.iloc[0,0]
# Out:
# 'Jupiter'

# %%
for i in range(10):
    row = random.randint(1,data.shape[0]-1)
    col = random.randint(1,data.shape[1]-1)
    data.iloc[row,col] = np.nan

# %%
data
# Out:
#     Planet  Mass (10^24kg)  Diameter (km)  Density (kg/m^3)  \
# 1  Mercury           0.330         4879.0              5429
# 2    Venus             NaN        12104.0              5243
# 3    Earth           5.970        12756.0              5514
# 4     Mars           0.642         6792.0              3934
# 5  Jupiter        1898.000       142984.0              1326
# 6   Saturn         568.000            NaN               687
# 7   Uranus          86.800        51118.0              1270
# 8  Neptune             NaN        49528.0              1638
#
#    Surface Gravity(m/s^2)  Escape Velocity (km/s)  Rotation Period (hours)  \
# 1                     3.7                     4.3                   1407.6
# 2                     8.9                     NaN                      NaN
# 3                     9.8                     NaN                     23.9
# 4                     3.7                     5.0                     24.6
# ...

# %%
data.isnull().sum()
# Out:
# Planet                         0
# Mass (10^24kg)                 2
# Diameter (km)                  1
# Density (kg/m^3)               0
# Surface Gravity(m/s^2)         2
# Escape Velocity (km/s)         2
# Rotation Period (hours)        2
# Length of Day (hours)          0
# Distance from Sun (10^6 km)    0
# dtype: int64

# %%
data.drop('Escape Velocity (km/s)',axis = 1,inplace = True)

# %%
data
# Out:
#     Planet  Mass (10^24kg)  Diameter (km)  Density (kg/m^3)  \
# 1  Mercury           0.330         4879.0              5429
# 2    Venus             NaN        12104.0              5243
# 3    Earth           5.970        12756.0              5514
# 4     Mars           0.642         6792.0              3934
# 5  Jupiter        1898.000       142984.0              1326
# 6   Saturn         568.000            NaN               687
# 7   Uranus          86.800        51118.0              1270
# 8  Neptune             NaN        49528.0              1638
#
#    Surface Gravity(m/s^2)  Rotation Period (hours)  Length of Day (hours)  \
# 1                     3.7                   1407.6                 4222.6
# 2                     8.9                      NaN                 2802.0
# 3                     9.8                     23.9                   24.0
# 4                     3.7                     24.6                   24.7
# ...

# %%
val = data.iloc[[5,7],[4]].mean()
data['Surface Gravity(m/s^2)']=data['Surface Gravity(m/s^2)'].fillna(val[0])

# %%
data
# Out:
#     Planet  Mass (10^24kg)  Diameter (km)  Density (kg/m^3)  \
# 1  Mercury           0.330         4879.0              5429
# 2    Venus             NaN        12104.0              5243
# 3    Earth           5.970        12756.0              5514
# 4     Mars           0.642         6792.0              3934
# 5  Jupiter        1898.000       142984.0              1326
# 6   Saturn         568.000            NaN               687
# 7   Uranus          86.800        51118.0              1270
# 8  Neptune             NaN        49528.0              1638
#
#    Surface Gravity(m/s^2)  Rotation Period (hours)  Length of Day (hours)  \
# 1                     3.7                   1407.6                 4222.6
# 2                     8.9                      NaN                 2802.0
# 3                     9.8                     23.9                   24.0
# 4                     3.7                     24.6                   24.7
# ...

# %%
data.iloc[4,6] = 10

# %%
data
# Out:
#     Planet  Mass (10^24kg)  Diameter (km)  Density (kg/m^3)  \
# 1  Mercury           0.330         4879.0              5429
# 2    Venus             NaN        12104.0              5243
# 3    Earth           5.970        12756.0              5514
# 4     Mars           0.642         6792.0              3934
# 5  Jupiter        1898.000       142984.0              1326
# 6   Saturn         568.000            NaN               687
# 7   Uranus          86.800        51118.0              1270
# 8  Neptune             NaN        49528.0              1638
#
#    Surface Gravity(m/s^2)  Rotation Period (hours)  Length of Day (hours)  \
# 1                     3.7                   1407.6                 4222.6
# 2                     8.9                      NaN                 2802.0
# 3                     9.8                     23.9                   24.0
# 4                     3.7                     24.6                   24.7
# ...

# %%
data.iloc[1,6] = 5832

# %%
data
# Out:
#     Planet  Mass (10^24kg)  Diameter (km)  Density (kg/m^3)  \
# 1  Mercury           0.330         4879.0              5429
# 2    Venus             NaN        12104.0              5243
# 3    Earth           5.970        12756.0              5514
# 4     Mars           0.642         6792.0              3934
# 5  Jupiter        1898.000       142984.0              1326
# 6   Saturn         568.000            NaN               687
# 7   Uranus          86.800        51118.0              1270
# 8  Neptune             NaN        49528.0              1638
#
#    Surface Gravity(m/s^2)  Rotation Period (hours)  Length of Day (hours)  \
# 1                     3.7                   1407.6                 4222.6
# 2                     8.9                      NaN                 5832.0
# 3                     9.8                     23.9                   24.0
# 4                     3.7                     24.6                   24.7
# ...

# %%
data
# Out:
#     Planet  Mass (10^24kg)  Diameter (km)  Density (kg/m^3)  \
# 1  Mercury           0.330         4879.0              5429
# 2    Venus             NaN        12104.0              5243
# 3    Earth           5.970        12756.0              5514
# 4     Mars           0.642         6792.0              3934
# 5  Jupiter        1898.000       142984.0              1326
# 6   Saturn         568.000            NaN               687
# 7   Uranus          86.800        51118.0              1270
# 8  Neptune             NaN        49528.0              1638
#
#    Surface Gravity(m/s^2)  Rotation Period (hours)  Length of Day (hours)  \
# 1                     3.7                   1407.6                 4222.6
# 2                     8.9                      NaN                 5832.0
# 3                     9.8                     23.9                   24.0
# 4                     3.7                     24.6                   24.7
# ...

# %%
data.drop('Mass (10^24kg)',axis = 1, inplace = True)

# %%
data
# Out:
#     Planet  Density (kg/m^3)  Surface Gravity(m/s^2)  Rotation Period (hours)  \
# 1  Mercury              5429                     3.7                   1407.6
# 2    Venus              5243                     8.9                      NaN
# 3    Earth              5514                     9.8                     23.9
# 4     Mars              3934                     3.7                     24.6
# 5  Jupiter              1326                    11.0                      9.9
# 6   Saturn               687                    11.0                     10.7
# 7   Uranus              1270                     8.7                    -17.2
# 8  Neptune              1638                    11.0                      NaN
#
#    Length of Day (hours)  Distance from Sun (10^6 km)
# 1                 4222.6                         57.9
# 2                 5832.0                        108.2
# 3                   24.0                        149.6
# ...

# %%
data.columns = ['Planets','Density','Gravity','Rotation','DayLength','FromSun']

# %%
data
# Out:
#    Planets  Density  Gravity  Rotation  DayLength  FromSun
# 1  Mercury     5429      3.7    1407.6     4222.6     57.9
# 2    Venus     5243      8.9       NaN     5832.0    108.2
# 3    Earth     5514      9.8      23.9       24.0    149.6
# 4     Mars     3934      3.7      24.6       24.7    228.0
# 5  Jupiter     1326     11.0       9.9       10.0    778.5
# 6   Saturn      687     11.0      10.7       10.7   1432.0
# 7   Uranus     1270      8.7     -17.2       17.2   2867.0
# 8  Neptune     1638     11.0       NaN       16.1   4515.0

# %%
density = data['Density'].mean()
density
# Out:
# 3130.125

# %%
data.iloc[4,2] = 23.5

# %%
Strongest_Gravitational_Force = data['Gravity'].max()

# %%
Strongest_Gravitational_Force
# Out:
# 23.5

# %%
for i in range(8):
    if data.iloc[i,2] == Strongest_Gravitational_Force:
        print(data.iloc[i,0])
# Out:
# Jupiter

# %%
val = data['Rotation'].copy()

# %%
data.drop(['Rotation'], axis = 1,inplace = True)

# %%
val2 = data['Density'].copy()

# %%
data.drop(['Density'],axis =1 ,inplace = True)

# %%
val
# Out:
# 1    1407.6
# 2       NaN
# 3      23.9
# 4      24.6
# 5       9.9
# 6      10.7
# 7     -17.2
# 8       NaN
# Name: Rotation, dtype: float64

# %%
val2
# Out:
# 1    5429
# 2    5243
# 3    5514
# 4    3934
# 5    1326
# 6     687
# 7    1270
# 8    1638
# Name: Density, dtype: int64

# %%
val1 = pd.concat([val,val2],axis =1)

# %%
val1
# Out:
#    Rotation  Density
# 1    1407.6     5429
# 2       NaN     5243
# 3      23.9     5514
# 4      24.6     3934
# 5       9.9     1326
# 6      10.7      687
# 7     -17.2     1270
# 8       NaN     1638

# %%
data = pd.concat([data,val1],axis = 1)

# %%
data
# Out:
#    Planets  Gravity  DayLength  FromSun  Rotation  Density
# 1  Mercury      3.7     4222.6     57.9    1407.6     5429
# 2    Venus      8.9     5832.0    108.2       NaN     5243
# 3    Earth      9.8       24.0    149.6      23.9     5514
# 4     Mars      3.7       24.7    228.0      24.6     3934
# 5  Jupiter     23.5       10.0    778.5       9.9     1326
# 6   Saturn     11.0       10.7   1432.0      10.7      687
# 7   Uranus      8.7       17.2   2867.0     -17.2     1270
# 8  Neptune     11.0       16.1   4515.0       NaN     1638

# %%
data['DayLength'] = data['DayLength'].fillna(24)

# %%
data
# Out:
#    Planets  Gravity  DayLength  FromSun  Rotation  Density
# 1  Mercury      3.7     4222.6     57.9    1407.6     5429
# 2    Venus      8.9     5832.0    108.2       NaN     5243
# 3    Earth      9.8       24.0    149.6      23.9     5514
# 4     Mars      3.7       24.7    228.0      24.6     3934
# 5  Jupiter     23.5       10.0    778.5       9.9     1326
# 6   Saturn     11.0       10.7   1432.0      10.7      687
# 7   Uranus      8.7       17.2   2867.0     -17.2     1270
# 8  Neptune     11.0       16.1   4515.0       NaN     1638

# %%
data['Rotation']= data['Rotation'].fillna(16)

# %%
data.dropna(axis = 1,inplace = True)

# %%
data
# Out:
#    Planets  Gravity  DayLength  FromSun  Rotation  Density
# 1  Mercury      3.7     4222.6     57.9    1407.6     5429
# 2    Venus      8.9     5832.0    108.2      16.0     5243
# 3    Earth      9.8       24.0    149.6      23.9     5514
# 4     Mars      3.7       24.7    228.0      24.6     3934
# 5  Jupiter     23.5       10.0    778.5       9.9     1326
# 6   Saturn     11.0       10.7   1432.0      10.7      687
# 7   Uranus      8.7       17.2   2867.0     -17.2     1270
# 8  Neptune     11.0       16.1   4515.0      16.0     1638

# %%
plt.plot(data['Planets'],data['Gravity'],color = 'orange',linestyle='--',linewidth = 1.5)
plt.xlabel('Planets')
plt.ylabel('Gravity(m/s)')
plt.title('Gravity Line Graph')
plt.show()

# %%
plt.bar(data['Planets'],data['DayLength'],width = 0.5)
plt.title('DayLength')
plt.show()

# %%
data
# Out:
#    Planets  Gravity  DayLength  FromSun  Rotation  Density
# 1  Mercury      3.7     4222.6     57.9    1407.6     5429
# 2    Venus      8.9     5832.0    108.2      16.0     5243
# 3    Earth      9.8       24.0    149.6      23.9     5514
# 4     Mars      3.7       24.7    228.0      24.6     3934
# 5  Jupiter     23.5       10.0    778.5       9.9     1326
# 6   Saturn     11.0       10.7   1432.0      10.7      687
# 7   Uranus      8.7       17.2   2867.0     -17.2     1270
# 8  Neptune     11.0       16.1   4515.0      16.0     1638

# %%
data.iloc[6,4] = 17

# %%
data
# Out:
#    Planets  Gravity  DayLength  FromSun  Rotation  Density
# 1  Mercury      3.7     4222.6     57.9    1407.6     5429
# 2    Venus      8.9     5832.0    108.2      16.0     5243
# 3    Earth      9.8       24.0    149.6      23.9     5514
# 4     Mars      3.7       24.7    228.0      24.6     3934
# 5  Jupiter     23.5       10.0    778.5       9.9     1326
# 6   Saturn     11.0       10.7   1432.0      10.7      687
# 7   Uranus      8.7       17.2   2867.0      17.0     1270
# 8  Neptune     11.0       16.1   4515.0      16.0     1638

# %%
plt.pie(data['FromSun'],autopct = '%2.2f%%')
plt.legend(data['Planets'],loc = (1.9,0.5))
plt.show()

# %%
data
# Out:
#    Planets  Gravity  DayLength  FromSun  Rotation  Density
# 1  Mercury      3.7     4222.6     57.9    1407.6     5429
# 2    Venus      8.9     5832.0    108.2      16.0     5243
# 3    Earth      9.8       24.0    149.6      23.9     5514
# 4     Mars      3.7       24.7    228.0      24.6     3934
# 5  Jupiter     23.5       10.0    778.5       9.9     1326
# 6   Saturn     11.0       10.7   1432.0      10.7      687
# 7   Uranus      8.7       17.2   2867.0      17.0     1270
# 8  Neptune     11.0       16.1   4515.0      16.0     1638

# %%
data.iloc[[0,1],[2]] = [176,243]
data.iloc[0,4] = 57

# %%
fig , ax = plt.subplots(2,2,figsize = (8,8))
ax[0,0].plot(data['Planets'],data['Rotation'])
ax[0,0].set_title('Rotation')
ax[0,1].bar(data['Planets'],data['DayLength'] , hatch = '/')
ax[0,1].set_title('DayLength')
ax[1,0].hist(data['FromSun'],cumulative = True,bins = 18)
ax[1,0].set_title('FromSun')
ax[1,1].boxplot(data['Density'])
ax[1,1].set_title('Density')
plt.show()

# %%
ax = plt.axes(projection = '3d')
arr = np.random.normal(170,1.5,1000)
arr2 = np.random.normal(150,0.75,1000)
ax.set_xlabel('X-axis', labelpad=10)
ax.set_ylabel('Y-axis', labelpad=10)
ax.set_zlabel('Z-axis', labelpad=10)
ax.set_title('3D Scatter Plot', pad=20)
ax.scatter(arr,arr2)

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(-50, 50, 100)
y = np.linspace(-50, 50, 100)
X, Y = np.meshgrid(x, y)
Z = np.sin(X) * np.cos(Y)

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

surf = ax.plot_surface(X, Y, Z, cmap='plasma')

ax.set_xlabel('X-axis', labelpad=10)
ax.set_ylabel('Y-axis', labelpad=10)
ax.set_zlabel('Z-axis', labelpad=10)
ax.set_title('3D Surface Plot', pad=20)

fig.colorbar(surf, ax=ax, shrink=0.5, aspect=10)

plt.show()
